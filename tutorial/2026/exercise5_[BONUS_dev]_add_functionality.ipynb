# %% [markdown]
# # 5.BONUS: Add your own functionality to Puma
# This bonus exercise is for developers that would like to learn how to contribute to the Puma open source project. The CONTRIBUTING.md describes how to add new Appium actions to get an introduction to how Puma is built and how to add new functionality.
#
# Feel free to ask us for help to get started!

# %%
# This ensures changes to the classes are applied without needing to re-instantiate the class
# %load_ext autoreload
# %autoreload 2

# %%
from package import yourApp

# Set device udid. If your device udid is different, run adb devices and change the udid
device_udid = "emulator-5554"

your_app = YourApp(device_udid)
your_app.your_app_function()
