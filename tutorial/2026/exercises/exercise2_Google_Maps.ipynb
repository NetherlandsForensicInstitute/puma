# %% [markdown]
# # Exercise 2: Use Puma to navigate in Google Maps by spoofing the location
# In this exercise, you will navigate a route in Google Maps, by supplying a start and end location. You will be able to adjust the speed to the conditions during the run.
# Warn use a landmark or an exact address, give examples that work

# %% [markdown]
# First, configure your start and end point. The route will be calculated by OpenStreetMap. Your given start and end locations will be used to generate a realistic navigation path.
# **Important:** Both the start and end locations must be recognizable **landmarks** (e.g., a well‑known building, park, or intersection). OpenStreetMap resolves these names to geographic coordinates, so ambiguous or non‑existent names will cause the routing request to fail.
# You can use any of the following types of landmarks:
# - **Famous places** – e.g., Eiffel Tower, Statue of Liberty.,
# - **Public facilities** – e.g., Central Park, Times Square.
# - **Street intersections** – e.g., 5th Avenue & 42nd Street.
#
# If you prefer precise coordinates, you may also provide latitude/longitude pairs (e.g., `48.8584, 2.2945`). The routing engine will treat them as exact points.
#
# Once the landmarks are set, the script will request a route from the OpenStreetMap **OSRM** service, parse the returned geometry, and feed it to the Puma `RouteSimulator` for playback on the device.
#
# Feel free to experiment with different start/end combinations to see how the simulated navigation behaves. Enter your location in the `search()` below to check if the location can be found:

# %%
from puma.apps.android.google_maps.google_maps import GoogleMapsActions

maps = GoogleMapsActions()
maps.search_place(search_string="") # Enter here

# %% [markdown]
# Then, enter your start and end locations and start the navigation

# %%
from puma.apps.android.google_maps.google_maps import GoogleMapsActions

start_location = ""
end_location = ""

# %%
maps = GoogleMapsActions()
maps.
