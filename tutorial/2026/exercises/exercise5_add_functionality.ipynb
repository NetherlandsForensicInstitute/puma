# %% [markdown]
# [Stretch] Add some explanation from former tutorial and let them choose an application to add functionality to

# %% [markdown]
# Choose any application you want. If you own an Android phone, you could even send a message to someone in WhatsApp.
