# %% [markdown]
# # Welcome to the Puma Tutorial
#
# Puma — *Programmable Utility for Mobile Automation* — is a Python library that lets you control Android apps through simple, high‑level actions.
# It supports a variety of popular applications such as **Telegram**, **TeleGuard**, **WhatsApp**, **Google Maps**, and more (See the README.md)
#
# In this tutorial you will learn how to use Puma to interact with the a few of these apps: Sending messages with TeleGuard, navigating using Google Maps and conduct websearches using Google Chrome. Finally, you will build a full scenario, using multiple application simultaneously to mimick real user behaviour.
#
# The workshop is primarily aimed at _using_ Puma. If you’re interested in extending Puma itself or adding support for new apps, check out bonus **Exercise 5**. Please refer to the [CONTRIBUTING.md](../../CONTRIBUTING.md) for guidelines, or ask one of us for help.

# %% [markdown]
# # Exercise 1: Send us a message with TeleGuard
# In this exercise, you will learn to use Puma through a few simple actions.
# We will add a contact and send a message using the chat app TeleGuard. TeleGuard does not require personal information such as a phone number, making it the perfect candidate for a tutorial!
#
# > ❔ New to jupyter notebooks? You need to run all executable cells sequentially in order to initialize the variables. Weird behaviour and/or crashes? Restart the kernel and rerun the code blocks, top of screen: Kernel -> Restart Kernel...
#
# Your TeleGuard ID is displayed in a "chat" with TeleGuard, and can be shared with other users to message one another.
#
# Fill in your device udid and initialize TeleGuard.
#
# The device udid can be found by running
# ```bash
# adb devices
# ```
# from your terminal. If you use an emulator, the udid has already been filled in, as emulators have default udids. For physical devices, the udid is unique for the device and always needs to be checked.

# %%
from puma.apps.android.teleguard.teleguard import TeleGuard

# This initializes an object through which we can execute TeleGuard actions. Initialization can take a while. The device udid can be found by running `adb devices` in your terminal
teleguard = TeleGuard(device_udid="emulator-5554")
# Out:
# 2026-03-12 14:22:52 [INFO] [adb_pywrapper] Using Android SDK ROOT /home/bouke/Android/Sdk
# 2026-03-12 14:22:52 [INFO] [puma.state_graph] Connecting to Appium driver...

# %% [markdown]
# You probably got an error stating Appium is not running. To establish a connection to the Appium driver, we need to start Appium first.
# In a terminal, run the command
# ```bash
# appium
# ```
# Then rerun the above code.

# %% [markdown]
# ### Appium
# Appium is a framework for testing applications, based on Selenium. In Puma, we use Appium to execute actions on the device.
# In this context, we define functions in Python that exist of one or more `Appium actions`. An Appium action is an action on the phone, for instance tapping on an element. In our Python code, we define functions executing one or more
# Appium actions, for instance `send_message()` where the message box is tapped, text is added to the box and the send button is clicked.

# %% [markdown]
# ## 1. Add a contact
# To send messages, you need to have someone to talk to. This can be done by adding a contact.
# If you are attending a workshop, the TeleGuard ID of the workshop host is visible on screen, add them! If you are doing the tutorial by yourself, create an additional TeleGuard ID on another device, or ask someone else to do it. Enter the ID in the cell below and execute the code:

# %%
contact_id = 'E3XU9VEYV' # TeleGuard ID of the person you want to add
teleguard.add_contact(contact_id)
# Out:
# 2026-03-12 14:24:11 [INFO] [32131JEHN38079] Validated that current state is the expected state 'conversations_state'
# 2026-03-12 14:24:11 [INFO] [32131JEHN38079] Executing action 'add_contact' with arguments: ('D3ADARV4E',) and keyword arguments: {} for application: TeleGuard
# 2026-03-12 14:24:14 [INFO] [32131JEHN38079] Entering text "D3ADARV4E" in text box
# 2026-03-12 14:24:17 [INFO] [32131JEHN38079] Executed action 'add_contact' with arguments: ('D3ADARV4E',) and keyword arguments: {} for application: TeleGuard

# %% [markdown]
# ## 2. Send a message
# Send a message to the contact you just added. Enter their username and the message below.

# %%
recipient_username = 'Puma' # Username or group name you will send a message to
message = 'hello' # Message to send

teleguard.send_message(message=message, conversation=recipient_username)
# Out:
# 2026-03-12 14:26:51 [ERROR] [32131JEHN38079] Expected to be in state 'chat_state', but the validation failed
# 2026-03-12 14:26:51 [INFO] [32131JEHN38079] Recovering state to 'chat_state', current state is 'unknown'
# 2026-03-12 14:26:52 [INFO] [32131JEHN38079] Was in unknown state, expected 'chat_state'. Recognized state, setting current state to 'conversations_state'
# 2026-03-12 14:26:52 [INFO] [32131JEHN38079] Validated that current state is the expected state 'conversations_state'
# 2026-03-12 14:26:52 [INFO] [32131JEHN38079] Going from state 'conversations_state' to 'chat_state', calling transition 'go_to_chat'
# 2026-03-12 14:26:53 [INFO] [32131JEHN38079] Validated that current state is the expected state 'chat_state'
# 2026-03-12 14:26:53 [INFO] [32131JEHN38079] Executing action 'send_message' with arguments: ('Hello Bob, how are you?', 'BobTest') and keyword arguments: {} for application: TeleGuard
# 2026-03-12 14:26:54 [INFO] [32131JEHN38079] Entering text "Hello Bob, how are you?" in text box
# 2026-03-12 14:26:57 [INFO] [32131JEHN38079] Executed action 'send_message' with arguments: ('Hello Bob, how are you?', 'BobTest') and keyword arguments: {} for application: TeleGuard

# %% [markdown]
# ## 3. Send a picture with TeleGuard
# Apart from sending messages, Puma also supports sending pictures.Each application has a , listing all functionality of an application and the options. Sending a picture can be done in several ways, e.g. sending a picture from the gallery or taking a new picture with the camera. Lastly, an optional caption can be added.
# _Note_:
# `picture_id` is the index of the picture shown in the Android media picker (the first picture has index 1 ).
# If `picture_id` is omitted, TeleGuard will open the camera, take a picture, and send it.
# Caption is optional – you can omit it to send the image without text.

# %%
teleguard.send_picture(conversation="Puma",
                       #optional parameters, you can also remove them
                       picture_id=0, caption="")
# Out:
# 2026-03-12 14:36:31 [INFO] [32131JEHN38079] Validated that current state is the expected state 'chat_state'
# 2026-03-12 14:36:31 [INFO] [32131JEHN38079] Going from state 'chat_state' to 'send_media_state', calling transition 'go_to_send_media'
# 2026-03-12 14:36:32 [INFO] [32131JEHN38079] Validated that current state is the expected state 'send_media_state'
# 2026-03-12 14:36:32 [INFO] [32131JEHN38079] Executing action 'send_picture' with arguments: () and keyword arguments: {'conversation': 'BobTest', 'picture_id': 0, 'caption': ''} for application: TeleGuard
# 2026-03-12 14:36:43 [INFO] [32131JEHN38079] Failed to execute action 'send_picture'.
# 2026-03-12 14:36:43 [INFO] [32131JEHN38079] Recovering state to 'send_media_state', current state is 'unknown'
# 2026-03-12 14:36:45 [WARNING] [puma.state_graph] Not in a known state. Restarting app ch.swisscows.messenger.teleguardapp once
# 2026-03-12 14:36:45 [INFO] [32131JEHN38079] Terminating app ch.swisscows.messenger.teleguardapp
# 2026-03-12 14:36:45 [INFO] [32131JEHN38079] Activating app ch.swisscows.messenger.teleguardapp
# 2026-03-12 14:36:48 [ERROR] [32131JEHN38079] Expected to be in state 'send_media_state', but the validation failed
# 2026-03-12 14:36:48 [INFO] [32131JEHN38079] Recovering state to 'send_media_state', current state is 'unknown'
# 2026-03-12 14:36:50 [INFO] [32131JEHN38079] Was in unknown state, expected 'send_media_state'. Recognized state, setting current state to 'conversations_state'
# 2026-03-12 14:36:50 [INFO] [32131JEHN38079] Validated that current state is the expected state 'conversations_state'
# 2026-03-12 14:36:50 [INFO] [32131JEHN38079] Going from state 'conversations_state' to 'send_media_state', calling transition 'go_to_chat'
# 2026-03-12 14:36:51 [INFO] [32131JEHN38079] Validated that current state is the expected state 'chat_state'
# 2026-03-12 14:36:51 [INFO] [32131JEHN38079] Going from state 'chat_state' to 'send_media_state', calling transition 'go_to_send_media'
# 2026-03-12 14:36:52 [INFO] [32131JEHN38079] Validated that current state is the expected state 'send_media_state'
# 2026-03-12 14:36:52 [INFO] [32131JEHN38079] Retrying action 'send_picture'
# 2026-03-12 14:37:04 [ERROR] [32131JEHN38079] Unexpected exception while executing an action
# Traceback (most recent call last):
#   File "/home/bouke/dev/libraries/puma/puma/state_graph/action.py", line 110, in wrapper
#     result = func(*args, **kwargs)
#   File "/home/bouke/dev/libraries/puma/puma/apps/android/teleguard/teleguard.py", line 165, in send_picture
#     self.driver.click(CHAT_STATE_SEND_BUTTON)
#   File "/home/bouke/dev/libraries/puma/puma/state_graph/puma_driver.py", line 195, in click
#     raise PumaClickException(f'Could not click on non present element with xpath {xpath}')
# puma.state_graph.puma_driver.PumaClickException: Could not click on non present element with xpath //android.widget.FrameLayout[@resource-id="android:id/content"]/android.widget.FrameLayout/android.widget.FrameLayout/android.view.View/android.view.View/android.view.View/android.view.View/android.widget.ImageView[3]
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/bouke/dev/libraries/puma/puma/state_graph/action.py", line 116, in wrapper
#     result = func(*args, **kwargs)
#   File "/home/bouke/dev/libraries/puma/puma/apps/android/teleguard/teleguard.py", line 165, in send_picture
#     self.driver.click(CHAT_STATE_SEND_BUTTON)
#   File "/home/bouke/dev/libraries/puma/puma/state_graph/puma_driver.py", line 195, in click
#     raise PumaClickException(f'Could not click on non present element with xpath {xpath}')
# puma.state_graph.puma_driver.PumaClickException: Could not click on non present element with xpath //android.widget.FrameLayout[@resource-id="android:id/content"]/android.widget.FrameLayout/android.widget.FrameLayout/android.view.View/android.view.View/android.view.View/android.view.View/android.widget.ImageView[3]
# ---------------------------------------------------------------------------
# PumaClickException                        Traceback (most recent call last)
# File ~/dev/libraries/puma/puma/state_graph/action.py:110, in action.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     108     gtl_logger.info(
#     109         f"Executing action '{func.__name__}' with arguments: {args[1:]} and keyword arguments: {kwargs} for application: {puma_ui_graph.__class__.__name__}")
# --> 110     result = func(*args, **kwargs)
#     111 except:
#
# File ~/dev/libraries/puma/puma/apps/android/teleguard/teleguard.py:165, in TeleGuard.send_picture(self, picture_id, caption, conversation)
#     164     self.driver.send_keys(CHAT_STATE_TEXT_FIELD, caption)
# --> 165 self.driver.click(CHAT_STATE_SEND_BUTTON)
#
# File ~/dev/libraries/puma/puma/state_graph/puma_driver.py:195, in PumaDriver.click(self, xpath, width_ratio, height_ratio)
#     194         return
# --> 195 raise PumaClickException(f'Could not click on non present element with xpath {xpath}')
#
# PumaClickException: Could not click on non present element with xpath //android.widget.FrameLayout[@resource-id="android:id/content"]/android.widget.FrameLayout/android.widget.FrameLayout/android.view.View/android.view.View/android.view.View/android.view.View/android.widget.ImageView[3]
#
# During handling of the above exception, another exception occurred:
#
# PumaClickException                        Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 teleguard.send_picture(conversation="BobTest",
#       2                        #optional parameters, you can also remove them
#       3                        picture_id=0, caption="")
#
# File ~/dev/libraries/puma/puma/state_graph/action.py:132, in action.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     130 except Exception as e:
#     131     gtl_logger.exception("Unexpected exception while executing an action")
# --> 132     raise e
#
# File ~/dev/libraries/puma/puma/state_graph/action.py:116, in action.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     114     puma_ui_graph.go_to_state(state, **arguments)
#     115     gtl_logger.info(f"Retrying action '{func.__name__}'")
# --> 116     result = func(*args, **kwargs)
#     118 gtl_logger.info(
#     119         f"Executed action '{func.__name__}' with arguments: {args[1:]} and keyword arguments: {kwargs} for application: {puma_ui_graph.__class__.__name__}")
#     121 if verify_with is not None:
#
# File ~/dev/libraries/puma/puma/apps/android/teleguard/teleguard.py:165, in TeleGuard.send_picture(self, picture_id, caption, conversation)
#     163 if caption:
#     164     self.driver.send_keys(CHAT_STATE_TEXT_FIELD, caption)
# --> 165 self.driver.click(CHAT_STATE_SEND_BUTTON)
#
# File ~/dev/libraries/puma/puma/state_graph/puma_driver.py:195, in PumaDriver.click(self, xpath, width_ratio, height_ratio)
#     193             self.tap(location)
#     194         return
# --> 195 raise PumaClickException(f'Could not click on non present element with xpath {xpath}')
#
# PumaClickException: Could not click on non present element with xpath //android.widget.FrameLayout[@resource-id="android:id/content"]/android.widget.FrameLayout/android.widget.FrameLayout/android.view.View/android.view.View/android.view.View/android.view.View/android.widget.ImageView[3]

# %% [markdown]
# #### What to observe
# After running the cell, the TeleGuard app on the device should open the media picker (or camera) and automatically send the selected image.
# The caption (if provided) appears in the chat bubble alongside the picture.
# If you omitted picture_id, a new photo will be captured and sent.
# Feel free to experiment with different picture_id values or captions to see how the app behaves.
